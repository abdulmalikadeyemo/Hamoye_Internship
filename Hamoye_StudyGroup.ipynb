# %%
import pandas as pd

# %%
data = pd.read_csv('/content/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
data.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %% [markdown]
# **Question 1**

# %%
#Print columns
col = list(data.columns)

# %%
type(col)
# Out:
# list

# %%
print(col)
# Out:
# ['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element', 'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']

# %% [markdown]
# #Groupby

# %%
data.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
data.groupby(['Element']).mean()
# Out:
#                                          Area Code    Item Code  Element Code  \
# Element
# Domestic supply quantity                133.898584  2681.292729        5301.0
# Export Quantity                         136.250284  2689.201226        5911.0
# Fat supply quantity (g/capita/day)      134.391798  2694.604818         684.0
# Feed                                    133.640637  2682.719484        5521.0
# Food                                    134.243068  2688.734062        5142.0
# Food supply (kcal/capita/day)           134.434982  2694.666933         664.0
# Food supply quantity (kg/capita/yr)     134.239755  2688.155148         645.0
# Import Quantity                         133.912045  2684.562366        5611.0
# Losses                                  136.561971  2700.250373        5123.0
# Other uses (non-food)                   136.001155  2730.801963        5154.0
# Processing                              135.293532  2661.898507        5131.0
# ...

# %%
element_area_group = data.groupby(['Element','Area']).sum()

# %% [markdown]
# **Question: What is the total Domestic Supply Quantity in Algeria for the year 2018**

# %%
element_area_group.head(50)
# Out:
#                                                       Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                            464     311204
#                          Angola                             826     316106
#                          Benin                             6148     310985
#                          Botswana                          2340     313766
#                          Burkina Faso                     27494     316106
#                          Cabo Verde                        4025     308467
#                          Cameroon                          3808     318888
#                          Central African Republic          4292     310780
#                          Chad                              4641     318888
#                          Comoros                            405      24911
#                          Congo                             5474     318888
# ...

# %% [markdown]
# **WHat is the highest food suppy for 2018**

# %%
element_group = data.groupby(['Element']).min()

# %%
element_group
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2511
# Fat supply quantity (g/capita/day)              4  Algeria       2511
# Feed                                            4  Algeria       2511
# Food                                            4  Algeria       2511
# Food supply (kcal/capita/day)                   4  Algeria       2511
# Food supply quantity (kg/capita/yr)             4  Algeria       2511
# Import Quantity                                 4  Algeria       2511
# Losses                                          4  Algeria       2511
# Other uses (non-food)                           4  Algeria       2511
# Processing                                      4  Algeria       2511
# Production                                      4  Algeria       2511
# ...

# %%
len(set(data['Area']))
# Out:
# 46

# %%
element_area_group = list(element_area_group['Y2018'])
element_area_group.sort()

# %%
element_area_group[0]
# Out:
# -12667.0
